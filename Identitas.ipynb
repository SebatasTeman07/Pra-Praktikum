# %%
#Menampilkan Nama
print("Nama = Faza Mafatikhul Huda")
#Menampilkan NIM
print("NIM = 2605060012")
#Menampilkan Tempat Tanggal Lahir
print("Tempat Tanggal Lahir = Magelang 15 November 2007")
#Menampilkan Alamat
print("Alamat = Banjarsari Grabag Magelang Jawa Tengah")
#Menampilkan Jenis Kelamin
print("Jenis Kelamin = Laki-Laki")
#Menampilkan Hobi
print("Hobbi = Menonton Sepak Bola")
# Out:
# Nama = Faza Mafatikhul Huda
# NIM = 2605060012
# Tempat Tanggal Lahir = Magelang 15 November 2007
# Alamat = Banjarsari Grabag Magelang Jawa Tengah
# Jenis Kelamin = Laki-Laki
# Hobbi = Menonton Sepak Bola
